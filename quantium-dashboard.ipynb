# %% [markdown]
# # Imports

# %%
# !pip install "dash[testing]"
# Out:
# Collecting dash[testing]
#   Obtaining dependency information for dash[testing] from https://files.pythonhosted.org/packages/27/ad/7047095224013ec2ae37ba8ece5956773e7953c39a3af5aa20d821ed99aa/dash-2.17.1-py3-none-any.whl.metadata
#   Downloading dash-2.17.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\ahmed\anaconda3\lib\site-packages (from dash[testing]) (2.2.2)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\ahmed\anaconda3\lib\site-packages (from dash[testing]) (2.2.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\ahmed\anaconda3\lib\site-packages (from dash[testing]) (5.9.0)
# Collecting dash-html-components==2.0.0 (from dash[testing])
#   Obtaining dependency information for dash-html-components==2.0.0 from https://files.pythonhosted.org/packages/75/65/1b16b853844ef59b2742a7de74a598f376ac0ab581f0dcc34db294e5c90e/dash_html_components-2.0.0-py3-none-any.whl.metadata
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash[testing])
#   Obtaining dependency information for dash-core-components==2.0.0 from https://files.pythonhosted.org/packages/00/9e/a29f726e84e531a36d56cff187e61d8c96d2cc253c5bcef9a7695acb7e6a/dash_core_components-2.0.0-py3-none-any.whl.metadata
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash[testing])
#   Obtaining dependency information for dash-table==5.0.0 from https://files.pythonhosted.org/packages/da/ce/43f77dc8e7bbad02a9f88d07bf794eaf68359df756a28bb9f2f78e255bb1/dash_table-5.0.0-py3-none-any.whl.metadata
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: importlib-metadata in c:\users\ahmed\anaconda3\lib\site-packages (from dash[testing]) (6.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\ahmed\anaconda3\lib\site-packages (from dash[testing]) (4.7.1)
# Requirement already satisfied: requests in c:\users\ahmed\anaconda3\lib\site-packages (from dash[testing]) (2.31.0)
# Collecting retrying (from dash[testing])
#   Obtaining dependency information for retrying from https://files.pythonhosted.org/packages/8f/04/9e36f28be4c0532c0e9207ff9dc01fb13a2b0eb036476a213b0000837d0e/retrying-1.3.4-py3-none-any.whl.metadata
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in c:\users\ahmed\appdata\roaming\python\python311\site-packages (from dash[testing]) (1.5.6)
# Requirement already satisfied: setuptools in c:\users\ahmed\anaconda3\lib\site-packages (from dash[testing]) (68.0.0)
# Requirement already satisfied: beautifulsoup4>=4.8.2 in c:\users\ahmed\anaconda3\lib\site-packages (from dash[testing]) (4.12.2)
# Requirement already satisfied: cryptography in c:\users\ahmed\anaconda3\lib\site-packages (from dash[testing]) (41.0.2)
# Requirement already satisfied: lxml>=4.6.2 in c:\users\ahmed\anaconda3\lib\site-packages (from dash[testing]) (4.9.2)
# Collecting percy>=2.0.2 (from dash[testing])
#   Obtaining dependency information for percy>=2.0.2 from https://files.pythonhosted.org/packages/d6/39/528e689e21baa4d625cecc326c0d56c976d63855f9d114c07ccaed8a73eb/percy-2.0.2-py2.py3-none-any.whl.metadata
#   Downloading percy-2.0.2-py2.py3-none-any.whl.metadata (821 bytes)
# Requirement already satisfied: pytest>=6.0.2 in c:\users\ahmed\anaconda3\lib\site-packages (from dash[testing]) (7.4.0)
# Collecting selenium<=4.2.0,>=3.141.0 (from dash[testing])
#   Obtaining dependency information for selenium<=4.2.0,>=3.141.0 from https://files.pythonhosted.org/packages/c9/0b/5ef429492faa5d951d8215918c7092de2dbc25cf895fdf46643260b22f92/selenium-4.2.0-py3-none-any.whl.metadata
#   Downloading selenium-4.2.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting waitress>=1.4.4 (from dash[testing])
#   Obtaining dependency information for waitress>=1.4.4 from https://files.pythonhosted.org/packages/5b/a9/485c953a1ac4cb98c28e41fd2c7184072df36bbf99734a51d44d04176878/waitress-3.0.0-py3-none-any.whl.metadata
#   Downloading waitress-3.0.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting multiprocess>=0.70.12 (from dash[testing])
#   Obtaining dependency information for multiprocess>=0.70.12 from https://files.pythonhosted.org/packages/50/15/b56e50e8debaf439f44befec5b2af11db85f6e0f344c3113ae0be0593a91/multiprocess-0.70.16-py311-none-any.whl.metadata
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\ahmed\appdata\roaming\python\python311\site-packages (from dash[testing]) (5.9.5)
# Collecting dash-testing-stub>=0.0.2 (from dash[testing])
#   Obtaining dependency information for dash-testing-stub>=0.0.2 from https://files.pythonhosted.org/packages/42/67/56de4c8eab3932150fb046250dc25f7c5d772958352e78c0192bb2b328e8/dash_testing_stub-0.0.2-py3-none-any.whl.metadata
#   Downloading dash_testing_stub-0.0.2-py3-none-any.whl.metadata (587 bytes)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ahmed\anaconda3\lib\site-packages (from beautifulsoup4>=4.8.2->dash[testing]) (2.4)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\ahmed\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash[testing]) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\ahmed\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash[testing]) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\ahmed\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash[testing]) (8.0.4)
# Collecting dill>=0.3.8 (from multiprocess>=0.70.12->dash[testing])
#   Obtaining dependency information for dill>=0.3.8 from https://files.pythonhosted.org/packages/c9/7a/cef76fd8438a42f96db64ddaa85280485a9c395e7df3db8158cfec1eee34/dill-0.3.8-py3-none-any.whl.metadata
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ahmed\anaconda3\lib\site-packages (from plotly>=5.0.0->dash[testing]) (8.2.2)
# Requirement already satisfied: iniconfig in c:\users\ahmed\anaconda3\lib\site-packages (from pytest>=6.0.2->dash[testing]) (1.1.1)
# Requirement already satisfied: packaging in c:\users\ahmed\appdata\roaming\python\python311\site-packages (from pytest>=6.0.2->dash[testing]) (23.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\ahmed\anaconda3\lib\site-packages (from pytest>=6.0.2->dash[testing]) (1.0.0)
# Requirement already satisfied: colorama in c:\users\ahmed\appdata\roaming\python\python311\site-packages (from pytest>=6.0.2->dash[testing]) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ahmed\anaconda3\lib\site-packages (from requests->dash[testing]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ahmed\anaconda3\lib\site-packages (from requests->dash[testing]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ahmed\anaconda3\lib\site-packages (from requests->dash[testing]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ahmed\anaconda3\lib\site-packages (from requests->dash[testing]) (2023.7.22)
# Collecting trio~=0.17 (from selenium<=4.2.0,>=3.141.0->dash[testing])
#   Obtaining dependency information for trio~=0.17 from https://files.pythonhosted.org/packages/76/51/12d78ec8abcbda51d8f115d98ebd3ee3da9d9d9af00ac69d3097c5b8d51a/trio-0.25.1-py3-none-any.whl.metadata
#   Downloading trio-0.25.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting trio-websocket~=0.9 (from selenium<=4.2.0,>=3.141.0->dash[testing])
#   Obtaining dependency information for trio-websocket~=0.9 from https://files.pythonhosted.org/packages/48/be/a9ae5f50cad5b6f85bd2574c2c923730098530096e170c1ce7452394d7aa/trio_websocket-0.11.1-py3-none-any.whl.metadata
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ahmed\anaconda3\lib\site-packages (from Werkzeug<3.1->dash[testing]) (2.1.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\ahmed\anaconda3\lib\site-packages (from cryptography->dash[testing]) (1.15.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\ahmed\anaconda3\lib\site-packages (from importlib-metadata->dash[testing]) (3.11.0)
# Requirement already satisfied: six>=1.7.0 in c:\users\ahmed\appdata\roaming\python\python311\site-packages (from retrying->dash[testing]) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\ahmed\anaconda3\lib\site-packages (from cffi>=1.12->cryptography->dash[testing]) (2.21)
# Collecting attrs>=23.2.0 (from trio~=0.17->selenium<=4.2.0,>=3.141.0->dash[testing])
#   Obtaining dependency information for attrs>=23.2.0 from https://files.pythonhosted.org/packages/e0/44/827b2a91a5816512fcaf3cc4ebc465ccd5d598c45cefa6703fcf4a79018f/attrs-23.2.0-py3-none-any.whl.metadata
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: sortedcontainers in c:\users\ahmed\anaconda3\lib\site-packages (from trio~=0.17->selenium<=4.2.0,>=3.141.0->dash[testing]) (2.4.0)
# Collecting outcome (from trio~=0.17->selenium<=4.2.0,>=3.141.0->dash[testing])
#   Obtaining dependency information for outcome from https://files.pythonhosted.org/packages/55/8b/5ab7257531a5d830fc8000c476e63c935488d74609b50f9384a643ec0a62/outcome-1.3.0.post0-py2.py3-none-any.whl.metadata
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.3.0 (from trio~=0.17->selenium<=4.2.0,>=3.141.0->dash[testing])
#   Obtaining dependency information for sniffio>=1.3.0 from https://files.pythonhosted.org/packages/e9/44/75a9c9421471a6c4805dbf2356f7c181a29c1879239abab1ea2cc8f38b40/sniffio-1.3.1-py3-none-any.whl.metadata
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium<=4.2.0,>=3.141.0->dash[testing])
#   Obtaining dependency information for wsproto>=0.14 from https://files.pythonhosted.org/packages/78/58/e860788190eba3bcce367f74d29c4675466ce8dddfba85f7827588416f01/wsproto-1.2.0-py3-none-any.whl.metadata
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\ahmed\anaconda3\lib\site-packages (from urllib3<3,>=1.21.1->requests->dash[testing]) (23.2.0)
# Collecting urllib3-secure-extra (from urllib3<3,>=1.21.1->requests->dash[testing])
#   Obtaining dependency information for urllib3-secure-extra from https://files.pythonhosted.org/packages/90/cd/273b6978ace72ef1d3f35610206e44e4527d557500e3d7b39732f2b4dd3c/urllib3_secure_extra-0.1.0-py2.py3-none-any.whl.metadata
#   Downloading urllib3_secure_extra-0.1.0-py2.py3-none-any.whl.metadata (828 bytes)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\ahmed\anaconda3\lib\site-packages (from urllib3<3,>=1.21.1->requests->dash[testing]) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium<=4.2.0,>=3.141.0->dash[testing])
#   Obtaining dependency information for h11<1,>=0.9.0 from https://files.pythonhosted.org/packages/95/04/ff642e65ad6b90db43e668d70ffb6736436c7ce41fcc549f4e9472234127/h11-0.14.0-py3-none-any.whl.metadata
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading dash_testing_stub-0.0.2-py3-none-any.whl (2.6 kB)
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ---------------------------------------- 0.0/143.5 kB ? eta -:--:--
#    -------- ------------------------------- 30.7/143.5 kB 1.3 MB/s eta 0:00:01
#    ---------------- ---------------------- 61.4/143.5 kB 656.4 kB/s eta 0:00:01
#    ----------------------------- -------- 112.6/143.5 kB 939.4 kB/s eta 0:00:01
#    -------------------------------------- 143.5/143.5 kB 945.2 kB/s eta 0:00:00
# Downloading percy-2.0.2-py2.py3-none-any.whl (12 kB)
# Downloading selenium-4.2.0-py3-none-any.whl (983 kB)
#    ---------------------------------------- 0.0/983.2 kB ? eta -:--:--
#    -- ------------------------------------- 61.4/983.2 kB 1.7 MB/s eta 0:00:01
#    ------ --------------------------------- 163.8/983.2 kB 1.6 MB/s eta 0:00:01
#    --------- ------------------------------ 245.8/983.2 kB 1.7 MB/s eta 0:00:01
#    ------------ --------------------------- 307.2/983.2 kB 1.7 MB/s eta 0:00:01
#    ------------ --------------------------- 307.2/983.2 kB 1.7 MB/s eta 0:00:01
#    ------------ --------------------------- 307.2/983.2 kB 1.7 MB/s eta 0:00:01
#    ------------ --------------------------- 307.2/983.2 kB 1.7 MB/s eta 0:00:01
#    ------------ --------------------------- 307.2/983.2 kB 1.7 MB/s eta 0:00:01
#    ------------ --------------------------- 307.2/983.2 kB 1.7 MB/s eta 0:00:01
#    ------------ --------------------------- 307.2/983.2 kB 1.7 MB/s eta 0:00:01
#    --------------------------------- ------ 829.4/983.2 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 849.9/983.2 kB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 901.1/983.2 kB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 931.8/983.2 kB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 942.1/983.2 kB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 942.1/983.2 kB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 942.1/983.2 kB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 942.1/983.2 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 983.2/983.2 kB 1.1 MB/s eta 0:00:00
# Downloading waitress-3.0.0-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.7 kB ? eta -:--:--
#    ------- -------------------------------- 10.2/56.7 kB ? eta -:--:--
#    ---------------------------------------- 56.7/56.7 kB 749.3 kB/s eta 0:00:00
# Downloading dash-2.17.1-py3-none-any.whl (7.5 MB)
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/7.5 MB 1.3 MB/s eta 0:00:06
#     --------------------------------------- 0.2/7.5 MB 1.5 MB/s eta 0:00:05
#    - -------------------------------------- 0.2/7.5 MB 1.8 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/7.5 MB 1.7 MB/s eta 0:00:05
#    -- ------------------------------------- 0.4/7.5 MB 1.7 MB/s eta 0:00:05
#    -- ------------------------------------- 0.5/7.5 MB 1.7 MB/s eta 0:00:04
#    --- ------------------------------------ 0.6/7.5 MB 1.8 MB/s eta 0:00:04
#    --- ------------------------------------ 0.7/7.5 MB 1.8 MB/s eta 0:00:04
#    --- ------------------------------------ 0.7/7.5 MB 1.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.8/7.5 MB 1.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.9/7.5 MB 1.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/7.5 MB 1.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.1/7.5 MB 1.8 MB/s eta 0:00:04
#    ------ --------------------------------- 1.2/7.5 MB 1.8 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/7.5 MB 1.8 MB/s eta 0:00:04
#    ------- -------------------------------- 1.4/7.5 MB 1.8 MB/s eta 0:00:04
#    ------- -------------------------------- 1.4/7.5 MB 1.8 MB/s eta 0:00:04
#    -------- ------------------------------- 1.5/7.5 MB 1.8 MB/s eta 0:00:04
#    -------- ------------------------------- 1.6/7.5 MB 1.8 MB/s eta 0:00:04
#    -------- ------------------------------- 1.7/7.5 MB 1.8 MB/s eta 0:00:04
#    --------- ------------------------------ 1.8/7.5 MB 1.8 MB/s eta 0:00:04
#    --------- ------------------------------ 1.9/7.5 MB 1.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 1.9/7.5 MB 1.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.0/7.5 MB 1.8 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.1/7.5 MB 1.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.2/7.5 MB 1.8 MB/s eta 0:00:03
#    ------------ --------------------------- 2.3/7.5 MB 1.8 MB/s eta 0:00:03
#    ------------ --------------------------- 2.4/7.5 MB 1.8 MB/s eta 0:00:03
#    ------------- -------------------------- 2.4/7.5 MB 1.8 MB/s eta 0:00:03
#    ------------- -------------------------- 2.5/7.5 MB 1.8 MB/s eta 0:00:03
#    ------------- -------------------------- 2.6/7.5 MB 1.8 MB/s eta 0:00:03
#    -------------- ------------------------- 2.7/7.5 MB 1.8 MB/s eta 0:00:03
#    -------------- ------------------------- 2.8/7.5 MB 1.8 MB/s eta 0:00:03
#    --------------- ------------------------ 2.9/7.5 MB 1.8 MB/s eta 0:00:03
#    --------------- ------------------------ 3.0/7.5 MB 1.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.0/7.5 MB 1.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.1/7.5 MB 1.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 3.2/7.5 MB 1.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 3.3/7.5 MB 1.8 MB/s eta 0:00:03
#    ------------------ --------------------- 3.4/7.5 MB 1.8 MB/s eta 0:00:03
#    ------------------ --------------------- 3.5/7.5 MB 1.8 MB/s eta 0:00:03
#    ------------------ --------------------- 3.6/7.5 MB 1.8 MB/s eta 0:00:03
#    ------------------- -------------------- 3.6/7.5 MB 1.8 MB/s eta 0:00:03
#    ------------------- -------------------- 3.7/7.5 MB 1.8 MB/s eta 0:00:03
#    -------------------- ------------------- 3.8/7.5 MB 1.8 MB/s eta 0:00:03
#    -------------------- ------------------- 3.9/7.5 MB 1.8 MB/s eta 0:00:02
#    --------------------- ------------------ 4.0/7.5 MB 1.8 MB/s eta 0:00:02
#    --------------------- ------------------ 4.1/7.5 MB 1.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.1/7.5 MB 1.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.2/7.5 MB 1.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.3/7.5 MB 1.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.4/7.5 MB 1.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.5/7.5 MB 1.8 MB/s eta 0:00:02
#    ------------------------ --------------- 4.6/7.5 MB 1.8 MB/s eta 0:00:02
#    ------------------------ --------------- 4.6/7.5 MB 1.8 MB/s eta 0:00:02
#    ------------------------- -------------- 4.7/7.5 MB 1.8 MB/s eta 0:00:02
#    ------------------------- -------------- 4.8/7.5 MB 1.8 MB/s eta 0:00:02
#    -------------------------- ------------- 4.9/7.5 MB 1.8 MB/s eta 0:00:02
#    -------------------------- ------------- 5.0/7.5 MB 1.8 MB/s eta 0:00:02
#    --------------------------- ------------ 5.1/7.5 MB 1.8 MB/s eta 0:00:02
#    --------------------------- ------------ 5.2/7.5 MB 1.8 MB/s eta 0:00:02
#    --------------------------- ------------ 5.2/7.5 MB 1.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.3/7.5 MB 1.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.4/7.5 MB 1.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.5/7.5 MB 1.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.6/7.5 MB 1.8 MB/s eta 0:00:02
#    ------------------------------ --------- 5.7/7.5 MB 1.8 MB/s eta 0:00:01
#    ------------------------------ --------- 5.7/7.5 MB 1.8 MB/s eta 0:00:01
#    ------------------------------- -------- 5.8/7.5 MB 1.8 MB/s eta 0:00:01
#    ------------------------------- -------- 5.9/7.5 MB 1.8 MB/s eta 0:00:01
#    -------------------------------- ------- 6.0/7.5 MB 1.8 MB/s eta 0:00:01
#    -------------------------------- ------- 6.1/7.5 MB 1.8 MB/s eta 0:00:01
#    --------------------------------- ------ 6.2/7.5 MB 1.8 MB/s eta 0:00:01
#    --------------------------------- ------ 6.3/7.5 MB 1.8 MB/s eta 0:00:01
#    --------------------------------- ------ 6.3/7.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.4/7.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.5/7.5 MB 1.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.6/7.5 MB 1.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.7/7.5 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 6.8/7.5 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 6.9/7.5 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------- -- 6.9/7.5 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------- -- 7.0/7.5 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------- -- 7.1/7.5 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 7.2/7.5 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 7.3/7.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  7.4/7.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  7.4/7.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 7.5/7.5 MB 1.8 MB/s eta 0:00:00
# Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ---------------------------------------- 0.0/116.3 kB ? eta -:--:--
#    --------------------- ------------------ 61.4/116.3 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 116.3/116.3 kB 1.7 MB/s eta 0:00:00
# Downloading trio-0.25.1-py3-none-any.whl (467 kB)
#    ---------------------------------------- 0.0/467.7 kB ? eta -:--:--
#    ----- ---------------------------------- 61.4/467.7 kB 1.7 MB/s eta 0:00:01
#    ------------ --------------------------- 143.4/467.7 kB 2.1 MB/s eta 0:00:01
#    --------------------- ------------------ 245.8/467.7 kB 1.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 327.7/467.7 kB 1.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 409.6/467.7 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 467.7/467.7 kB 1.8 MB/s eta 0:00:00
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#    ---------------------------------------- 60.8/60.8 kB 3.4 MB/s eta 0:00:00
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading urllib3_secure_extra-0.1.0-py2.py3-none-any.whl (1.4 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: urllib3-secure-extra, dash-testing-stub, dash-table, dash-html-components, dash-core-components, waitress, sniffio, retrying, h11, dill, attrs, wsproto, percy, outcome, multiprocess, trio, dash, trio-websocket, selenium
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.2.0
#     Uninstalling sniffio-1.2.0:
#       Successfully uninstalled sniffio-1.2.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.6
#     Uninstalling dill-0.3.6:
#       Successfully uninstalled dill-0.3.6
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
# Successfully installed attrs-23.2.0 dash-2.17.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 dash-testing-stub-0.0.2 dill-0.3.8 h11-0.14.0 multiprocess-0.70.16 outcome-1.3.0.post0 percy-2.0.2 retrying-1.3.4 selenium-4.2.0 sniffio-1.3.1 trio-0.25.1 trio-websocket-0.11.1 urllib3-secure-extra-0.1.0 waitress-3.0.0 wsproto-1.2.0

# %%
import pandas as pd
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.express as px

# %% [markdown]
# # Reading csv files

# %%
# reading files
first_daily_sales = pd.read_csv('./data/daily_sales_data_0.csv')
second_daily_sales = pd.read_csv('./data/daily_sales_data_1.csv')
third_daily_sales = pd.read_csv('./data/daily_sales_data_2.csv')

# %%
# first transactions
print(first_daily_sales.shape)
first_daily_sales.head()
# Out:
# (13720, 5)
#        product  price  quantity        date region
# 0  pink morsel  $3.00       546  2018-02-06  north
# 1  pink morsel  $3.00       549  2018-02-06  south
# 2  pink morsel  $3.00       577  2018-02-06   east
# 3  pink morsel  $3.00       519  2018-02-06   west
# 4  gold morsel  $9.99       580  2018-02-06  north

# %%
# second transactions
print(second_daily_sales.shape)
second_daily_sales.head()
# Out:
# (13720, 5)
#        product  price  quantity        date region
# 0  pink morsel  $3.00       545  2019-06-11  north
# 1  pink morsel  $3.00       521  2019-06-11  south
# 2  pink morsel  $3.00       595  2019-06-11   east
# 3  pink morsel  $3.00       507  2019-06-11   west
# 4  gold morsel  $9.99       529  2019-06-11  north

# %%
# third day transactions
print(third_daily_sales.shape)
third_daily_sales.head()
# Out:
# (13720, 5)
#        product  price  quantity        date region
# 0  pink morsel  $3.00       526  2020-10-13  north
# 1  pink morsel  $3.00       546  2020-10-13  south
# 2  pink morsel  $3.00       505  2020-10-13   east
# 3  pink morsel  $3.00       561  2020-10-13   west
# 4  gold morsel  $9.99       553  2020-10-13  north

# %%
# all csv transactions combined
daily_sales = pd.concat([first_daily_sales, second_daily_sales, third_daily_sales])
print(daily_sales.shape)
daily_sales.head()
# Out:
# (41160, 5)
#        product  price  quantity        date region
# 0  pink morsel  $3.00       546  2018-02-06  north
# 1  pink morsel  $3.00       549  2018-02-06  south
# 2  pink morsel  $3.00       577  2018-02-06   east
# 3  pink morsel  $3.00       519  2018-02-06   west
# 4  gold morsel  $9.99       580  2018-02-06  north

# %% [markdown]
# # Data processing

# %%
# checking for null values, dtypes, and values consistencies
daily_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41160 entries, 0 to 13719
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   product   41160 non-null  object
#  1   price     41160 non-null  object
#  2   quantity  41160 non-null  int64
#  3   date      41160 non-null  object
#  4   region    41160 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.9+ MB

# %%
daily_sales['product'].unique()
# Out:
# array(['pink morsel', 'gold morsel', 'magenta morsel',
#        'chartreuse morsel', 'periwinkle morsel', 'vermilion morsel',
#        'lapis morsel'], dtype=object)

# %%
daily_sales['price'] = daily_sales['price'].str.replace("$", "", regex=False).astype(float)
daily_sales['price'].unique()
# Out:
# array([3.  , 9.99, 2.5 , 1.25, 4.99, 1.99, 5.  ])

# %%
daily_sales['quantity'] = daily_sales['quantity'].astype(int)
daily_sales['quantity'].unique()
# Out:
# array([546, 549, 577, 519, 580, 530, 576, 522, 560, 583, 552, 543, 574,
#        503, 506, 559, 533, 568, 556, 573, 544, 532, 585, 529, 566, 514,
#        545, 512, 524, 594, 596, 537, 547, 501, 548, 578, 504, 561, 581,
#        550, 518, 558, 536, 534, 567, 590, 515, 557, 600, 542, 535, 510,
#        579, 511, 500, 520, 565, 586, 554, 505, 597, 584, 553, 588, 540,
#        591, 525, 575, 509, 517, 523, 562, 569, 571, 599, 570, 521, 508,
#        516, 589, 572, 551, 541, 531, 502, 507, 538, 564, 527, 598, 595,
#        582, 526, 555, 593, 563, 528, 539, 513, 587, 592, 405, 439, 436,
#        479, 414, 446, 408, 476, 450, 434, 470, 490, 431, 409, 466, 472,
#        483, 480, 415, 440, 444, 460, 424, 430, 422, 429, 468, 478, 487,
#        473, 484, 499, 489, 461, 454, 402, 445, 447, 417, 498, 467, 401,
#        495, 464, 421, 418, 406, 400, 497, 491, 493, 458, 433, 404, 403,
#        449, 425, 481, 496, 410, 482, 465, 416, 437, 459, 428, 438, 455,
#        453, 413, 469, 474, 471, 419, 435, 448, 423, 488, 432, 407, 494,
#        411, 463, 420, 426, 451, 457, 492, 475, 485, 442, 486, 441, 456,
#        462, 477, 412, 443, 452, 427])

# %%
daily_sales['date'] = pd.to_datetime(daily_sales['date'])
daily_sales['date'].unique()
# Out:
# array(['2018-02-06T00:00:00.000000000', '2018-02-07T00:00:00.000000000',
#        '2018-02-08T00:00:00.000000000', ...,
#        '2022-02-12T00:00:00.000000000', '2022-02-13T00:00:00.000000000',
#        '2022-02-14T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
daily_sales['region'].unique()
# Out:
# array(['north', 'south', 'east', 'west'], dtype=object)

# %%
daily_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41160 entries, 0 to 13719
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   product   41160 non-null  object
#  1   price     41160 non-null  float64
#  2   quantity  41160 non-null  int32
#  3   date      41160 non-null  datetime64[ns]
#  4   region    41160 non-null  object
# dtypes: datetime64[ns](1), float64(1), int32(1), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# # Dashboard

# %%
# adding features to use later
daily_sales['profit'] = daily_sales['price'] * daily_sales['quantity']
daily_sales['year_month'] = daily_sales['date'].dt.to_period('M')
daily_sales['year'] = daily_sales['date'].dt.year

# filter for 'pink morsels'
pink_morsels_df = daily_sales[daily_sales['product'] == 'pink morsel']
pink_morsels_df.head()
# Out:
#         product  price  quantity       date region  profit year_month  year
# 0   pink morsel    3.0       546 2018-02-06  north  1638.0    2018-02  2018
# 1   pink morsel    3.0       549 2018-02-06  south  1647.0    2018-02  2018
# 2   pink morsel    3.0       577 2018-02-06   east  1731.0    2018-02  2018
# 3   pink morsel    3.0       519 2018-02-06   west  1557.0    2018-02  2018
# 28  pink morsel    3.0       529 2018-02-07  north  1587.0    2018-02  2018

# %%
# Initialize the Dash app
app = dash.Dash(__name__)

# Define the layout
app.layout = html.Div([
    html.H1("Pink Morsel Sales Dashboard"),
    dcc.Graph(id='profit-line-graph'),
    dcc.Graph(id='qty-line-graph'),
    dcc.Graph(id='profitability'),
    dcc.Store(id='pink-morsels-data', data=pink_morsels_df.reset_index(drop=True).to_json())
])


# Define callback to update graphs
@app.callback(
    [Output('profit-line-graph', 'figure'),
     Output('qty-line-graph', 'figure'),
     Output('profitability', 'figure')],
    [Input('pink-morsels-data', 'data')]
)
def update_graphs(pink_morsels_json):
    # Load the DataFrame from JSON
    pink_morsels_df = pd.read_json(pink_morsels_json)

    # Profit per Month
    pink_morsels_df['year_month'] = pink_morsels_df['year_month'].apply(lambda x: pd.to_datetime(f"{x['year']}-{x['month']}"))
    sales_line_fig = px.line(
        pink_morsels_df[['year_month', 'profit']].groupby('year_month')['profit'].mean().reset_index(), x='year_month', y='profit', title='Pink Morsel Profits Over Months',
        hover_data={'year_month': True, 'profit': True}
    )

    # Quantity Sold per Month
    qty_line_fig = px.line(
        pink_morsels_df[['year_month', 'quantity']].groupby('year_month')['quantity'].sum().reset_index(), x='year_month', y='quantity', title='Pink Morsel QTY. Sold Over Months',
        hover_data={'year_month': True, 'quantity': True}
    )

    # Profitability per region
    profitability_fig = px.bar(
        pink_morsels_df.groupby('region')['profit'].mean(),
        title='Profit per Region',
        barmode='group'
    )

    return sales_line_fig, qty_line_fig, profitability_fig


# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
